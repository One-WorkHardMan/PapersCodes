# %% [markdown]
# 定义Unet，基于时间的ScoreNet

# %%
import torch;
import torch.nn as nn;
import torch.nn.functional as F;
import numpy as np;
import functools;

# %%
class TimeEmbedding(nn.Module):

    "使用高斯随机特征进行 时间的embedding"

    def __init__(self,embed_dim,scale = 30.):
        super().__init__()
        self.w = nn.Parameter(torch.randn(embed_dim // 2)*scale,requires_grad=False)
    def forward(self,x):#传入的是时间t [32]
        x_proj = x[:,None] * self.w[None,:]*2*np.pi # None 是用来添加一个维度的，x变成了三维
        return torch.cat([torch.sin(x_proj),torch.cos(x_proj)],dim=-1) #[32,128]+[32,128]->[32,256]

# %% [markdown]
# MLP扩大维度

# %%
class Dense(nn.Module):
    def __init__(self,input_dim,output_dim):
        super().__init__()
        self.dense = nn.Linear(input_dim,output_dim)

    def forward(self,x):
        return self.dense(x)[...,None,None] #...就是前面所有维度的意思 ,最后返回的tensor应该是 以第一层为例，[1,32,1,1]

# %%
#定义ScoreNet

class ScoreNet(nn.Module):
    def __init__(self,marginal_prob_std,channels=[32,64,128,256],embed_dim = 256):
        super().__init__()
        #时间编码层
        self.embed = nn.Sequential(
            TimeEmbedding(embed_dim),
            nn.Linear(embed_dim,embed_dim)
        )
        #Unet编码层

        self.conv1 = nn.Conv2d(1,channels[0],3,stride=1,bias=False);
        self.dense1 = Dense(embed_dim,channels[0])
        self.gnorm1 = nn.GroupNorm(4,num_channels=channels[0])

        self.conv2  = nn.Conv2d(channels[0],channels[1],3,stride=2,bias=False)
        self.dense2 = Dense(embed_dim,channels[1])
        self.gnorm2 = nn.GroupNorm(32,num_channels=channels[1])

        self.conv3 = nn.Conv2d(channels[1],channels[2],3,stride=2,bias=False)
        self.dense3 = Dense(embed_dim,channels[2])
        self.gnorm3 = nn.GroupNorm(32,num_channels=channels[2])

        self.conv4 = nn.Conv2d(channels[2],channels[3],3,stride=2,bias=False)
        self.dense4 = Dense(embed_dim,channels[3])
        self.gnorm4 = nn.GroupNorm(32,num_channels=channels[3])

        #Unet解码器
        self.tconv4 = nn.ConvTranspose2d(channels[3],channels[2],3,stride=2,bias=False)
        self.dense5 = Dense(embed_dim,channels[2])
        self.tgnorm4 = nn.GroupNorm(32,num_channels=channels[2])

        self.tconv3 = nn.ConvTranspose2d(channels[2]+channels[2],channels[1],3,stride=2,bias=False,output_padding=1)
        self.dense6 = Dense(embed_dim,channels[1])
        self.tgnorm3 = nn.GroupNorm(32,num_channels=channels[1])

        self.tconv2 = nn.ConvTranspose2d(channels[1]+channels[1],channels[0],3,stride=2,bias=False,output_padding=1)
        self.dense7 = Dense(embed_dim,channels[0])
        self.tgnorm2 = nn.GroupNorm(32,num_channels=channels[0])

        #激活函数Swish
        self.act = lambda x:x*torch.sigmoid(x)

        self.tconv1 = nn.ConvTranspose2d(channels[0]+channels[0],1,3,stride=1)
        self.marginal_prob_std = marginal_prob_std

    def forward(self,x,t):
        embed = self.act(self.embed(t))
        print("经过时间embed之后，时间t的shape：",self.embed(t).shape) #torch.Size([32, 256])

        h1 = self.conv1(x)
        h1 += self.dense1(embed) #注入时间，后面也是一样的
        h1 =self.gnorm1(h1)
        h1 = self.act(h1)

        h2 = self.conv2(h1)
        h2 += self.dense2(embed)
        h2 = self.gnorm2(h2)
        h2 = self.act(h2)

        h3 = self.conv3(h2)
        h3 += self.dense3(embed)
        h3 = self.gnorm3(h3)
        h3 = self.act(h3)

        h4 = self.conv4(h3)
        h4 += self.dense4(embed)
        h4 = self.gnorm4(h4)
        h4 = self.act(h4)

#       解码器部分前向计算
        h = self.tconv4(h4)
        h+= self.dense5(embed)
        h = self.tgnorm4(h)
        h = self.act(h)
        # 按照channel那一个维度拼起来
        print("h:",h.shape)#torch.Size([32, 128, 5, 5]
        print(h3.shape)
        h = self.tconv3(torch.cat([h,h3],dim = 1))
        h += self.dense6(embed)
        h = self.tgnorm3(h)
        h = self.act(h)

        h =self.tconv2(torch.cat([h,h2],dim=1))
        h += self.dense7(embed)
        h = self.tgnorm2(h)
        h = self.act(h)

        h = self.tconv1(torch.cat([h,h1],dim=1))

        h = h/self.marginal_prob_std(t)[:,None,None,None] #SDE 里面对每个Unet的结果除以 2范数 平方的期望，希望我们预测分数可以逼近真实的分数
        return h

# %% [markdown]
# ![来自内容的路径](Images/Images_for_ScoreBasedModel/20230322172639.png "相对路径演示")
# 定义损失函数，SDE,这里对SDE进行了简化，去掉了漂移系数，只保留了扩散系数。
# https://zhuanlan.zhihu.com/p/399968951
# ![来自内容的路径](Images/Images_for_ScoreBasedModel/20230331004844.png "相对路径演示")

# %%
device = 'cuda' #cuda

def marginal_prob_std(t,sigma):
# 定义标准差，这里还把时间t给引入进来了，在分数模型2019中没有时间t，那个t只在郎之万采样的时候用了；这里的t带入就可以得到某一个噪声sigma下，不同t时刻的 扰动数据的 概率分布，也是近似于一个高斯分布；
    t = torch.tensor(t,device = device)
    return torch.sqrt((sigma**(2*t)-1.)/(2.*(np.log(sigma))))

def diffusion_coeff(t,sigma):
    return torch.tensor(sigma**t,device=device)
# 扩散系数
sigma = 25.0
# 构造无参函数：
marginal_prob_std_fn = functools.partial(marginal_prob_std,sigma = sigma)
diffusion_coeff_fn = functools.partial(diffusion_coeff,sigma = sigma)

# %% [markdown]
# ![路径](Images/Images_for_ScoreBasedModel/20230327171159.png) "loss的定义"

# %%
def loss_fn(score_model,x,marginal_prob_std,eps = 1e-5):
    # 生成时间  t  ,一个时间t 对应 一张图片；
    random_t = torch.rand(x.shape[0],device=x.device)*(1 - eps)+eps
    print("random_t",random_t.shape,"random_t",random_t) #[32]
    # 基于参数重整化技巧添加扰动数据
    z =torch.randn_like(x)
    print("z",z.shape) #[32,1,28,28]
    #t时刻的标准差
    std = marginal_prob_std(random_t)

    #SDE这个加噪的方式，怎么也是参数重整化？仔细看上上个cell
    perturbed_x = x + z*std[:,None,None,None]

    # 传入扰动数据和时间t ，得到 分数score。
    score = score_model(perturbed_x,random_t)
    print("score.shape:",score.shape)#[32,1,28,28]
    print("std",std,std.shape)#[32]

# (score*std[:,None,None,None]+z)**2 分数乘以标准差+一个噪声z
    print(torch.sum((score*std[:,None,None,None]+z)**2,dim=(1,2,3)).shape)#[32]  可以看出来这个sum是把32个图像中每个图像的CHW维度数据全部加起来成一个值；然后再对32个图像取mean。
    print(torch.sum((score*std[:,None,None,None]+z)**2,dim=(1)).shape)
    print(torch.sum((score*std[:,None,None,None]+z)**2,dim=(2)).shape)
    print(torch.sum((score*std[:,None,None,None]+z)**2,dim=(3)).shape)
#torch.Size([32, 28, 28])   torch.Size([32, 1, 28])     torch.Size([32, 1, 28])     loss tensor(4290.4404, device='cuda:0', grad_fn=<MeanBackward0>)
    loss = torch.mean(torch.sum((score*std[:,None,None,None]+z)**2,dim=(1,2,3)))
    print("loss",loss)
    return loss;

# %% [markdown]
# 编写EMA函数：对模型的权重进行指数平滑

# %%
from copy import deepcopy


#对权重 进行指数平滑
class EMA(nn.Module):
    def __init__(self,model,decay = 0.9999,device =None):
        super(EMA,self).__init__();#这是 python2 的写法，3的话不需要写EMA
        self.module = deepcopy(model)
        self.module.eval()
        self.decay = decay
        self.device = device
        if self.device is not None:
            self.module.to(device=device)
    def _update(self,model,update_fn):
        with torch.no_grad():
            #zip 把两个[] 组装成字典 {}
            for ema_v,model_v in zip(self.module.state_dict().values(),model.state_dict().values()):
                if self.device is not None:
                    model_v = model_v.to(device=device)
                ema_v.copy_(update_fn(ema_v,model_v))
    def update(self,model):
        self._update(model,update_fn=lambda e,m:self.decay*e+(1-self.decay)*m)
    def set(self,model):
        self._update(model,update_fn=lambda e,m:m)

# %% [markdown]
# 基于Minist数据集的模型

# %%
import torch
import functools
from torch.optim import Adam
from torch.utils.data import DataLoader
import torchvision.transforms as transformers
from torchvision.datasets import MNIST
import tqdm

# 多机多卡一般用DDP-分布式训练
score_model = torch.nn.DataParallel(ScoreNet(marginal_prob_std=marginal_prob_std_fn))
#将cuda 0 设置成主GPU
device = torch.device("cuda:0")
score_model = score_model.to(device)

n_epechs = 1
batch_size = 32
lr = 1e-4

#根目录下没有数据集就自己下载
dataset = MNIST('.',True,transform=transformers.ToTensor(),download=True);
#开启4个进程去做
data_loader = DataLoader(dataset,batch_size,shuffle=True,num_workers=4)
#torch.Size([32, 1, 28, 28])
# for x,y in data_loader:
#     print(x.shape)

optimizer = Adam(score_model.parameters(),lr=lr)
tqdm_epochs = tqdm.tqdm(range(n_epechs))

ema = EMA(score_model)
for epoch in tqdm_epochs:
    avg_loss = 0.0;
    num_items = 0
    # x是图片，y是标签，也就是condition，条件，但是这里我们是无条件生成；
    for x,y in data_loader:
        x= x.to(device)
        loss = loss_fn(score_model,x,marginal_prob_std_fn)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        #均值平滑
        ema.update(score_model)

        avg_loss += loss.item() * x.shape[0]
        num_items += x.shape[0]
    print("Average ScoreMatching Loss:{:5f}".format(avg_loss/num_items))
    #保存模型参数
    torch.save(score_model.state_dict(),f"ckpt_{epoch}.pth")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# random_t torch.Size([32]) random_t tensor([0.6480, 0.1370, 0.3794, 0.7943, 0.2419, 0.5927, 0.0962, 0.9840, 0.5290,
#         0.8001, 0.4745, 0.8542, 0.5952, 0.5344, 0.0647, 0.7283, 0.4906, 0.5260,
#         0.2051, 0.6520, 0.7042, 0.9579, 0.7833, 0.4356, 0.0882, 0.7626, 0.4233,
#         0.7621, 0.4400, 0.1801, 0.3459, 0.5212], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# C:\Users\26295\AppData\Local\Temp\ipykernel_15912\2303197657.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(t,device = device)
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.1485, 0.4688, 1.2772, 5.0659, 0.7627, 2.6262, 0.3649, 9.3513, 2.1269,
#         5.1618, 1.7718, 6.1495, 2.6476, 2.1660, 0.2832, 4.0904, 1.8707, 2.1061,
#         0.6529, 3.1898, 3.7820, 8.5952, 4.8887, 1.5526, 0.3446, 4.5717, 1.4880,
#         4.5644, 1.5761, 0.5829, 1.1336, 2.0727], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(6366.2500, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.0225, 0.1678, 0.4487, 0.5644, 0.6523, 0.1932, 0.6358, 0.2419, 0.9728,
#         0.6065, 0.9646, 0.6019, 0.5155, 0.1150, 0.9685, 0.6436, 0.9147, 0.6898,
#         0.1471, 0.7691, 0.6150, 0.6016, 0.6079, 0.1190, 0.0979, 0.4079, 0.1761,
#         0.6075, 0.5110, 0.9552, 0.8422, 0.7709], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.1558, 0.5498, 1.6233, 2.3920, 3.1929, 0.6192, 3.0257, 0.7628, 9.0177,
#         2.7482, 8.7830, 2.7073, 2.0339, 0.4128, 8.8934, 3.1036, 7.4779, 3.6085,
#         0.4951, 4.6693, 2.8264, 2.7040, 2.7607, 0.4228, 0.3694, 1.4109, 0.5721,
#         2.7574, 2.0035, 8.5200, 5.9153, 4.6962], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(5986.3730, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4354, 0.7199, 0.5359, 0.2376, 0.2301, 0.8601, 0.5053, 0.0043, 0.2932,
#         0.1826, 0.1630, 0.9498, 0.4039, 0.2282, 0.3357, 0.7400, 0.9929, 0.1875,
#         0.9501, 0.5179, 0.2433, 0.6980, 0.5969, 0.0629, 0.3351, 0.0963, 0.5082,
#         0.7993, 0.6047, 0.4491, 0.1945, 0.0090], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.5512, 3.9800, 2.1764, 0.7496, 0.7266, 6.2688, 1.9653, 0.0661, 0.9328,
#         0.5899, 0.5370, 8.3742, 1.3915, 0.7209, 1.0925, 4.2485, 9.6229, 0.6032,
#         8.3808, 2.0500, 0.7672, 3.7058, 2.6632, 0.2784, 1.0899, 0.3653, 1.9845,
#         5.1497, 2.7320, 1.6257, 0.6228, 0.0965], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(5639.5610, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8607, 0.8648, 0.2503, 0.7006, 0.4499, 0.7843, 0.7633, 0.8461, 0.1869,
#         0.8247, 0.8326, 0.5572, 0.8842, 0.7910, 0.0805, 0.6054, 0.6733, 0.8014,
#         0.7047, 0.1597, 0.1151, 0.5727, 0.4412, 0.5122, 0.1525, 0.0043, 0.1342,
#         0.8474, 0.5316, 0.6518, 0.8624, 0.3090], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([6.2807, 6.3631, 0.7893, 3.7378, 1.6301, 4.9047, 4.5822, 5.9906, 0.6016,
#         5.5909, 5.7359, 2.3362, 6.7766, 5.0121, 0.3247, 2.7381, 3.4196, 5.1839,
#         3.7879, 0.5280, 0.4129, 2.4586, 1.5823, 2.0110, 0.5092, 0.0660, 0.4618,
#         6.0170, 2.1457, 3.1876, 6.3159, 0.9900], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(5331.1997, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1483, 0.5106, 0.2695, 0.4143, 0.5213, 0.4539, 0.3748, 0.6008, 0.1461,
#         0.3794, 0.5169, 0.0210, 0.2560, 0.2023, 0.5524, 0.3531, 0.4764, 0.1119,
#         0.6546, 0.9377, 0.2488, 0.4074, 0.3856, 0.8857, 0.3006, 0.3181, 0.7082,
#         0.5228, 0.1506, 0.0432, 0.4826, 0.4587], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.4982, 2.0004, 0.8516, 1.4427, 2.0734, 1.6524, 1.2567, 2.6975, 0.4924,
#         1.2770, 2.0434, 0.1500, 0.8073, 0.6451, 2.2988, 1.1630, 1.7832, 0.4048,
#         3.2175, 8.0524, 0.7845, 1.4087, 1.3054, 6.8096, 0.9594, 1.0241, 3.8310,
#         2.0841, 0.5042, 0.2231, 1.8209, 1.6795], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(5385.0742, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1857, 0.3001, 0.7279, 0.2411, 0.5311, 0.4607, 0.6884, 0.3955, 0.0340,
#         0.8364, 0.5793, 0.7110, 0.6256, 0.5968, 0.3011, 0.0817, 0.7432, 0.4277,
#         0.1509, 0.8786, 0.9939, 0.7418, 0.4675, 0.8271, 0.6059, 0.9612, 0.3727,
#         0.5748, 0.0886, 0.1179, 0.5284, 0.8932], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.5985, 0.9577, 4.0850, 0.7602, 2.1422, 1.6909, 3.5919, 1.3514, 0.1950,
#         5.8064, 2.5127, 3.8660, 2.9257, 2.6621, 0.9611, 0.3278, 4.2935, 1.5107,
#         0.5049, 6.6547, 9.6548, 4.2734, 1.7309, 5.6345, 2.7425, 8.6872, 1.2474,
#         2.4760, 0.3456, 0.4201, 2.1229, 6.9751], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(4871.5747, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1336, 0.3983, 0.4683, 0.0083, 0.6424, 0.0722, 0.6206, 0.0597, 0.7313,
#         0.7493, 0.1992, 0.1281, 0.5318, 0.2507, 0.9936, 0.2869, 0.1406, 0.8572,
#         0.8565, 0.1787, 0.3829, 0.0904, 0.7036, 0.9743, 0.1620, 0.3329, 0.5173,
#         0.0176, 0.3852, 0.3204, 0.1675, 0.1143], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.4601, 1.3646, 1.7353, 0.0925, 3.0911, 0.3031, 2.8789, 0.2698, 4.1309,
#         4.3792, 0.6361, 0.4460, 2.1470, 0.7903, 9.6434, 0.9107, 0.4782, 6.2105,
#         6.1959, 0.5792, 1.2931, 0.3502, 3.7741, 9.0630, 0.5343, 1.0811, 2.0460,
#         0.1367, 1.3035, 1.0329, 0.5488, 0.4110], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(4486.0537, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.5746, 0.0776, 0.9046, 0.1540, 0.9219, 0.3357, 0.2784, 0.6243, 0.8829,
#         0.6513, 0.3985, 0.9643, 0.0915, 0.5343, 0.7164, 0.6011, 0.2665, 0.9533,
#         0.5472, 0.8726, 0.4785, 0.1775, 0.3700, 0.5364, 0.0922, 0.8417, 0.5935,
#         0.9632, 0.6726, 0.6884, 0.9237, 0.3401], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.4740, 0.3172, 7.2366, 0.5131, 7.6531, 1.0924, 0.8814, 2.9136, 6.7470,
#         3.1825, 1.3658, 8.7758, 0.3529, 2.1650, 3.9345, 2.6996, 0.8417, 8.4689,
#         2.2597, 6.5262, 1.7959, 0.5760, 1.2356, 2.1803, 0.3547, 5.9060, 2.6329,
#         8.7440, 3.4118, 3.5922, 7.6971, 1.1100], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(4543.4766, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.9234, 0.0559, 0.4663, 0.6787, 0.4283, 0.3339, 0.7267, 0.9106, 0.3666,
#         0.6379, 0.2763, 0.2965, 0.1358, 0.1819, 0.1492, 0.8989, 0.5080, 0.2634,
#         0.5616, 0.4267, 0.0512, 0.3960, 0.3330, 0.2825, 0.4505, 0.5220, 0.6594,
#         0.0765, 0.0229, 0.9913, 0.6012, 0.9724], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([7.6911, 0.2594, 1.7234, 3.4804, 1.5142, 1.0851, 4.0688, 7.3782, 1.2207,
#         3.0465, 0.8744, 0.9446, 0.4659, 0.5880, 0.5006, 7.1048, 1.9834, 0.8313,
#         2.3705, 1.5057, 0.2464, 1.3540, 1.0815, 0.8956, 1.6337, 2.0783, 3.2683,
#         0.3145, 0.1571, 9.5721, 2.7013, 9.0061], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(4299.0283, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8118, 0.0592, 0.8781, 0.9432, 0.5999, 0.2099, 0.6777, 0.6388, 0.9906,
#         0.8604, 0.6508, 0.8272, 0.8767, 0.7222, 0.7606, 0.6443, 0.7494, 0.6847,
#         0.6532, 0.9673, 0.5443, 0.4924, 0.6428, 0.0261, 0.7979, 0.6007, 0.8834,
#         0.1171, 0.5184, 0.2337, 0.7842, 0.2472], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([5.3622, 0.2685, 6.6441, 8.1968, 2.6898, 0.6668, 3.4693, 3.0551, 9.5523,
#         6.2746, 3.1780, 5.6350, 6.6130, 4.0104, 4.5427, 3.1109, 4.3803, 3.5488,
#         3.2025, 8.8607, 2.2379, 1.8825, 3.0956, 0.1685, 5.1262, 2.6961, 6.7585,
#         0.4180, 2.0531, 0.7376, 4.9036, 0.7793], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(4125.7192, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.0839, 0.9684, 0.0667, 0.6158, 0.6458, 0.5858, 0.2609, 0.4528, 0.5593,
#         0.5891, 0.1514, 0.3194, 0.8290, 0.0991, 0.9477, 0.9831, 0.0992, 0.2369,
#         0.7490, 0.4176, 0.4659, 0.1996, 0.0041, 0.8646, 0.5146, 0.7285, 0.8125,
#         0.3487, 0.5447, 0.3405, 0.8506, 0.4800], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.3335, 8.8904, 0.2885, 2.8337, 3.1266, 2.5672, 0.8233, 1.6464, 2.3523,
#         2.5958, 0.5064, 1.0292, 5.6694, 0.3723, 8.3166, 9.3223, 0.3726, 0.7473,
#         4.3744, 1.4590, 1.7213, 0.6373, 0.0645, 6.3598, 2.0272, 4.0932, 5.3745,
#         1.1450, 2.2409, 1.1116, 6.0782, 1.8052], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3970.5767, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3014, 0.9446, 0.1821, 0.4620, 0.6549, 0.9793, 0.4692, 0.7402, 0.2680,
#         0.3647, 0.1051, 0.5755, 0.6764, 0.5100, 0.3936, 0.0740, 0.2315, 0.4605,
#         0.9825, 0.6227, 0.0229, 0.7349, 0.0085, 0.3559, 0.1875, 0.1739, 0.9306,
#         0.7983, 0.5143, 0.9372, 0.9919, 0.6019], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.9622, 8.2336, 0.5886, 1.6988, 3.2209, 9.2104, 1.7406, 4.2512, 0.8466,
#         1.2124, 0.3876, 2.4813, 3.4542, 1.9966, 1.3425, 0.3079, 0.7309, 1.6898,
#         9.3050, 2.8985, 0.1571, 4.1791, 0.0932, 1.1749, 0.6033, 0.5661, 7.8708,
#         5.1333, 2.0254, 8.0410, 9.5919, 2.7068], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3866.4580, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.9623, 0.1107, 0.5022, 0.2699, 0.8108, 0.0483, 0.5517, 0.1263, 0.1875,
#         0.5301, 0.8382, 0.7327, 0.3047, 0.6649, 0.0478, 0.7365, 0.2962, 0.3918,
#         0.0016, 0.1114, 0.9219, 0.3111, 0.2149, 0.6161, 0.5530, 0.2446, 0.4518,
#         0.8398, 0.6267, 0.9282, 0.0716, 0.7953], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([8.7195, 0.4019, 1.9449, 0.8531, 5.3438, 0.2380, 2.2942, 0.4415, 0.6034,
#         2.1347, 5.8393, 4.1490, 0.9741, 3.3279, 0.2365, 4.2009, 0.9434, 1.3339,
#         0.0406, 0.4037, 7.6522, 0.9979, 0.6813, 2.8362, 2.3037, 0.7712, 1.6409,
#         5.8702, 2.9364, 7.8094, 0.3016, 5.0828], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3548.6965, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.9499, 0.6386, 0.5975, 0.0496, 0.2356, 0.9418, 0.4121, 0.8507, 0.6554,
#         0.1256, 0.1971, 0.0970, 0.3953, 0.5931, 0.0615, 0.1908, 0.9893, 0.9211,
#         0.5645, 0.0802, 0.2375, 0.5203, 0.5584, 0.8886, 0.6861, 0.3208, 0.0595,
#         0.1869, 0.5881, 0.4970, 0.5573, 0.2496], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([8.3756, 3.0538, 2.6686, 0.2417, 0.7432, 8.1601, 1.4317, 6.0810, 3.2260,
#         0.4398, 0.6301, 0.3671, 1.3503, 2.6300, 0.2748, 0.6125, 9.5112, 7.6342,
#         2.3930, 0.3241, 0.7492, 2.0663, 2.3451, 6.8717, 3.5657, 1.0345, 0.2692,
#         0.6016, 2.5867, 1.9114, 2.3371, 0.7870], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3423.6643, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4808, 0.8245, 0.5674, 0.8777, 0.4497, 0.5218, 0.9883, 0.6580, 0.2531,
#         0.3644, 0.9835, 0.9948, 0.8220, 0.3103, 0.8728, 0.3853, 0.3966, 0.4271,
#         0.5720, 0.1720, 0.5356, 0.6875, 0.0335, 0.9183, 0.2313, 0.3018, 0.6916,
#         0.7345, 0.4595, 0.9074, 0.7851, 0.9524], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.8101, 5.5874, 2.4161, 6.6343, 1.6289, 2.0765, 9.4808, 3.2535, 0.7981,
#         1.2110, 9.3339, 9.6810, 5.5424, 0.9950, 6.5312, 1.3042, 1.3564, 1.5079,
#         2.4531, 0.5610, 2.1747, 3.5821, 0.1933, 7.5634, 0.7302, 0.9636, 3.6303,
#         4.1730, 1.6843, 7.3039, 4.9178, 8.4448], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3477.3672, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6232, 0.1001, 0.2313, 0.0955, 0.0182, 0.1177, 0.4233, 0.5478, 0.0790,
#         0.8316, 0.0778, 0.2294, 0.0593, 0.3779, 0.1743, 0.2428, 0.4408, 0.5284,
#         0.0014, 0.7433, 0.4000, 0.1308, 0.7478, 0.3040, 0.7250, 0.7793, 0.9365,
#         0.5646, 0.7725, 0.3730, 0.5997, 0.7745], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.9027, 0.3748, 0.7303, 0.3632, 0.1390, 0.4196, 1.4881, 2.2641, 0.3209,
#         5.7159, 0.3178, 0.7244, 0.2687, 1.2704, 0.5673, 0.7656, 1.5806, 2.1232,
#         0.0375, 4.2938, 1.3728, 0.4531, 4.3578, 0.9717, 4.0465, 4.8262, 8.0208,
#         2.3938, 4.7204, 1.2485, 2.6872, 4.7524], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3131.0642, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4150, 0.3974, 0.0159, 0.1901, 0.8670, 0.9916, 0.9656, 0.9772, 0.7401,
#         0.5159, 0.6205, 0.7226, 0.1794, 0.5634, 0.4529, 0.2568, 0.0612, 0.9835,
#         0.8131, 0.1016, 0.2600, 0.8591, 0.6721, 0.9874, 0.5872, 0.1141, 0.1340,
#         0.4391, 0.1840, 0.1283, 0.7394, 0.2101], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.4464, 1.3606, 0.1293, 0.6105, 6.4103, 9.5832, 8.8111, 9.1474, 4.2503,
#         2.0366, 2.8779, 4.0151, 0.5812, 2.3845, 1.6471, 0.8101, 0.2738, 9.3341,
#         5.3847, 0.3787, 0.8203, 6.2483, 3.4064, 9.4519, 2.5788, 0.4103, 0.4611,
#         1.5710, 0.5937, 0.4467, 4.2403, 0.6673], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3076.0149, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6821, 0.3313, 0.6338, 0.1838, 0.5785, 0.0439, 0.1039, 0.3412, 0.9358,
#         0.8320, 0.4257, 0.6187, 0.1953, 0.2025, 0.4293, 0.1410, 0.9967, 0.8555,
#         0.4562, 0.4047, 0.7802, 0.8192, 0.0612, 0.1550, 0.4175, 0.1816, 0.9268,
#         0.7803, 0.7157, 0.9639, 0.0161, 0.5314], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.5188, 1.0749, 3.0060, 0.5933, 2.5065, 0.2253, 0.3845, 1.1143, 8.0037,
#         5.7237, 1.5004, 2.8607, 0.6252, 0.6455, 1.5195, 0.4794, 9.7409, 6.1758,
#         1.6654, 1.3956, 4.8408, 5.4917, 0.2738, 0.5158, 1.4585, 0.5870, 7.7741,
#         4.8414, 3.9260, 8.7630, 0.1304, 2.1446], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(3023.1221, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7689, 0.0427, 0.2946, 0.3037, 0.3840, 0.2126, 0.2231, 0.5755, 0.1597,
#         0.6917, 0.0853, 0.3233, 0.6659, 0.0289, 0.1163, 0.6987, 0.6150, 0.1644,
#         0.0249, 0.1552, 0.7706, 0.8523, 0.1527, 0.8666, 0.8685, 0.1996, 0.6497,
#         0.8939, 0.8685, 0.6271, 0.1237, 0.0074], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([4.6661, 0.2217, 0.9380, 0.9707, 1.2979, 0.6745, 0.7055, 2.4820, 0.5281,
#         3.6307, 0.3372, 1.0439, 3.3381, 0.1781, 0.4161, 3.7151, 2.8264, 0.5406,
#         0.1643, 0.5162, 4.6928, 6.1129, 0.5096, 6.4019, 6.4402, 0.6373, 3.1667,
#         6.9914, 6.4417, 2.9408, 0.4349, 0.0873], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2873.0786, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7321, 0.5061, 0.6119, 0.7392, 0.1344, 0.0867, 0.7061, 0.0128, 0.7024,
#         0.0896, 0.4530, 0.6943, 0.4973, 0.6926, 0.4425, 0.8766, 0.8736, 0.9884,
#         0.4518, 0.4307, 0.8190, 0.1610, 0.6043, 0.1728, 0.9372, 0.9007, 0.9438,
#         0.2799, 0.4364, 0.3610, 0.6231, 0.1923], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([4.1404, 1.9707, 2.7970, 4.2370, 0.4623, 0.3406, 3.8054, 0.1156, 3.7602,
#         0.3480, 1.6473, 3.6625, 1.9134, 3.6416, 1.5897, 6.6115, 6.5475, 9.4844,
#         1.6406, 1.5267, 5.4877, 0.5316, 2.7282, 0.5630, 8.0414, 7.1474, 8.2121,
#         0.8865, 1.5569, 1.1964, 2.9020, 0.6168], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2887.8032, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4941, 0.0932, 0.3799, 0.9703, 0.7828, 0.6323, 0.2821, 0.7567, 0.6622,
#         0.9273, 0.5559, 0.7333, 0.6227, 0.1260, 0.7371, 0.2137, 0.3206, 0.8557,
#         0.9355, 0.1734, 0.8483, 0.3678, 0.1342, 0.8815, 0.0864, 0.5762, 0.4541,
#         0.4090, 0.6529, 0.0497, 0.1529, 0.1843], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.8927, 0.3574, 1.2793, 8.9466, 4.8816, 2.9914, 0.8942, 4.4855, 3.2986,
#         7.7862, 2.3258, 4.1577, 2.8981, 0.4408, 4.2086, 0.6780, 1.0337, 6.1796,
#         7.9972, 0.5647, 6.0335, 1.2257, 0.4616, 6.7177, 0.3399, 2.4877, 1.6536,
#         1.4162, 3.1991, 0.2419, 0.5102, 0.5945], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2736.7947, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6349, 0.9884, 0.3495, 0.7917, 0.6529, 0.3137, 0.5437, 0.9640, 0.3261,
#         0.7705, 0.5129, 0.9988, 0.7938, 0.0015, 0.7752, 0.5257, 0.6593, 0.1897,
#         0.6651, 0.2895, 0.0273, 0.5736, 0.2957, 0.8504, 0.2633, 0.7117, 0.9970,
#         0.0807, 0.9728, 0.5545, 0.5867, 0.5426], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.0162, 9.4845, 1.1483, 5.0245, 3.1998, 1.0075, 2.2340, 8.7662, 1.0546,
#         4.6910, 2.0160, 9.8072, 5.0581, 0.0383, 4.7630, 2.1040, 3.2667, 0.6094,
#         3.3296, 0.9198, 0.1729, 2.4658, 0.9418, 6.0757, 0.8312, 3.8748, 9.7494,
#         0.3254, 9.0186, 2.3152, 2.5748, 2.2259], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2632.7644, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.0546, 0.2485, 0.5035, 0.6131, 0.7029, 0.1953, 0.3544, 0.1097, 0.1656,
#         0.8475, 0.9952, 0.4084, 0.6114, 0.4273, 0.5797, 0.8940, 0.3823, 0.4157,
#         0.7096, 0.1513, 0.3384, 0.7720, 0.1737, 0.9381, 0.5832, 0.9822, 0.6409,
#         0.9087, 0.0786, 0.9752, 0.2321, 0.5563], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.2559, 0.7834, 1.9538, 2.8087, 3.7658, 0.6252, 1.1686, 0.3993, 0.5438,
#         6.0186, 9.6927, 1.4136, 2.7929, 1.5088, 2.5160, 6.9929, 1.2904, 1.4496,
#         3.8495, 0.5061, 1.1029, 4.7140, 0.5656, 8.0630, 2.5452, 9.2961, 3.0766,
#         7.3340, 0.3199, 9.0897, 0.7326, 2.3289], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2576.7512, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4184, 0.1259, 0.3540, 0.1074, 0.2613, 0.3975, 0.3335, 0.3635, 0.1753,
#         0.3901, 0.1299, 0.1605, 0.5088, 0.7971, 0.4737, 0.7725, 0.9140, 0.8473,
#         0.9097, 0.8820, 0.3195, 0.6377, 0.7230, 0.5968, 0.2644, 0.4910, 0.6501,
#         0.4761, 0.6130, 0.8475, 0.1700, 0.8464], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.4630, 0.4406, 1.1667, 0.3935, 0.8246, 1.3610, 1.0838, 1.2071, 0.5699,
#         1.3261, 0.4508, 0.5304, 1.9885, 5.1121, 1.7672, 4.7208, 7.4599, 6.0134,
#         7.3576, 6.7270, 1.0292, 3.0447, 4.0205, 2.6619, 0.8347, 1.8731, 3.1702,
#         1.7814, 2.8080, 6.0178, 0.5555, 5.9977], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2588.6541, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6017, 0.2292, 0.3470, 0.6824, 0.5470, 0.1567, 0.6296, 0.6571, 0.1887,
#         0.2526, 0.8076, 0.7987, 0.2155, 0.6100, 0.0982, 0.8109, 0.2385, 0.7229,
#         0.2554, 0.6305, 0.9889, 0.1845, 0.7308, 0.0306, 0.1051, 0.1810, 0.9104,
#         0.4088, 0.1881, 0.7072, 0.3606, 0.2612], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.7055, 0.7240, 1.1380, 3.5230, 2.2584, 0.5202, 2.9651, 3.2432, 0.6066,
#         0.7965, 5.2901, 5.1386, 0.6830, 2.7798, 0.3700, 5.3469, 0.7523, 4.0188,
#         0.8055, 2.9729, 9.4986, 0.5951, 4.1238, 0.1840, 0.3877, 0.5855, 7.3747,
#         1.4153, 0.6051, 3.8190, 1.1947, 0.8242], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2409.2573, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3900, 0.4452, 0.4880, 0.0236, 0.8648, 0.5747, 0.5458, 0.3516, 0.5583,
#         0.8959, 0.9189, 0.7305, 0.6364, 0.6534, 0.3953, 0.9330, 0.5552, 0.1380,
#         0.1949, 0.5620, 0.4375, 0.8143, 0.9139, 0.8916, 0.6476, 0.5431, 0.6392,
#         0.5687, 0.2679, 0.3525, 0.1820, 0.3243], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.3257, 1.6045, 1.8545, 0.1595, 6.3636, 2.4748, 2.2496, 1.1570, 2.3443,
#         7.0361, 7.5790, 4.1194, 3.0310, 3.2046, 1.3504, 7.9327, 2.3207, 0.4715,
#         0.6241, 2.3733, 1.5628, 5.4057, 7.4565, 6.9397, 3.1446, 2.2296, 3.0592,
#         2.4268, 0.8464, 1.1608, 0.5881, 1.0479], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2406.2729, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8921, 0.8696, 0.7256, 0.6328, 0.2968, 0.5096, 0.5390, 0.1258, 0.0522,
#         0.3057, 0.5894, 0.7953, 0.0749, 0.7503, 0.1139, 0.9889, 0.8003, 0.4850,
#         0.2842, 0.5154, 0.4973, 0.3941, 0.8652, 0.2710, 0.9206, 0.0110, 0.7920,
#         0.2885, 0.8787, 0.9433, 0.7152, 0.9527], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([6.9499, 6.4643, 4.0550, 2.9963, 0.9456, 1.9936, 2.1988, 0.4401, 0.2491,
#         0.9778, 2.5980, 5.0835, 0.3103, 4.3931, 0.4100, 9.5004, 5.1663, 1.8361,
#         0.9016, 2.0331, 1.9131, 1.3448, 6.3722, 0.8567, 7.6199, 0.1067, 5.0297,
#         0.9165, 6.6559, 8.1989, 3.9201, 8.4516], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2253.7671, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7938, 0.8291, 0.0925, 0.7550, 0.4122, 0.5972, 0.5685, 0.7211, 0.8965,
#         0.6385, 0.5756, 0.9277, 0.7861, 0.8742, 0.6018, 0.9649, 0.1627, 0.7321,
#         0.7472, 0.9110, 0.0983, 0.2304, 0.6629, 0.2804, 0.6075, 0.4592, 0.5291,
#         0.6289, 0.3953, 0.6124, 0.8556, 0.3328], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([5.0579, 5.6710, 0.3556, 4.4611, 1.4324, 2.6652, 2.4252, 3.9957, 7.0496,
#         3.0521, 2.4826, 7.7986, 4.9340, 6.5604, 2.7063, 8.7908, 0.5361, 4.1410,
#         4.3486, 7.3871, 0.3703, 0.7275, 3.3053, 0.8883, 2.7569, 1.6827, 2.1277,
#         2.9578, 1.3505, 2.8024, 6.1781, 1.0810], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2224.5479, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2711, 0.9932, 0.5758, 0.0560, 0.7191, 0.2683, 0.1792, 0.6613, 0.1318,
#         0.9422, 0.5673, 0.3194, 0.4134, 0.7249, 0.6977, 0.4843, 0.2260, 0.1592,
#         0.8391, 0.1290, 0.0658, 0.6404, 0.5965, 0.3838, 0.7984, 0.2118, 0.4845,
#         0.5450, 0.0837, 0.9558, 0.4723, 0.0242], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.8570, 9.6314, 2.4843, 0.2598, 3.9697, 0.8475, 0.5806, 3.2886, 0.4557,
#         8.1719, 2.4152, 1.0290, 1.4381, 4.0446, 3.7029, 1.8314, 0.7143, 0.5268,
#         5.8573, 0.4485, 0.2863, 3.0710, 2.6597, 1.2973, 5.1339, 0.6724, 1.8326,
#         2.2433, 0.3330, 8.5370, 1.7591, 0.1616], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2121.7563, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4591, 0.8215, 0.1909, 0.7326, 0.2031, 0.6760, 0.2116, 0.1125, 0.9304,
#         0.1550, 0.8509, 0.0888, 0.7647, 0.7423, 0.7457, 0.2222, 0.1989, 0.3158,
#         0.6075, 0.5390, 0.8088, 0.4442, 0.9046, 0.5131, 0.8642, 0.3656, 0.1090,
#         0.3327, 0.5993, 0.1600, 0.4509, 0.3737], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.6819, 5.5330, 0.6127, 4.1476, 0.6473, 3.4500, 0.6717, 0.4065, 7.8668,
#         0.5158, 6.0839, 0.3462, 4.6027, 4.2810, 4.3277, 0.7029, 0.6353, 1.0155,
#         2.7572, 2.1988, 5.3092, 1.5990, 7.2380, 2.0172, 6.3520, 1.2162, 0.3976,
#         1.0804, 2.6840, 0.5288, 1.6359, 1.2520], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2030.9172, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7692, 0.1118, 0.1121, 0.6544, 0.4789, 0.0815, 0.6357, 0.5008, 0.1696,
#         0.6836, 0.2343, 0.8676, 0.1730, 0.5489, 0.4181, 0.0659, 0.8539, 0.2818,
#         0.4423, 0.1898, 0.2056, 0.5391, 0.2399, 0.3366, 0.5718, 0.1839, 0.9516,
#         0.1262, 0.8089, 0.8975, 0.0959, 0.1808], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([4.6706, 0.4047, 0.4054, 3.2155, 1.7986, 0.3274, 3.0246, 1.9357, 0.5546,
#         3.5366, 0.7394, 6.4212, 0.5636, 2.2725, 1.4616, 0.2865, 6.1443, 0.8933,
#         1.5884, 0.6096, 0.6545, 2.1996, 0.7566, 1.0960, 2.4512, 0.5935, 8.4223,
#         0.4412, 5.3120, 7.0723, 0.3642, 0.5849], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1903.0674, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7102, 0.4755, 0.7239, 0.4142, 0.6728, 0.8622, 0.1280, 0.9875, 0.0306,
#         0.7893, 0.7029, 0.5265, 0.4365, 0.8444, 0.5817, 0.0383, 0.2954, 0.3482,
#         0.2259, 0.9446, 0.0864, 0.0812, 0.9527, 0.3069, 0.5092, 0.1007, 0.0324,
#         0.9699, 0.6394, 0.1548, 0.6014, 0.5509], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.8569, 1.7778, 4.0317, 1.4424, 3.4140, 6.3110, 0.4459, 9.4568, 0.1840,
#         4.9855, 3.7664, 2.1099, 1.5572, 5.9582, 2.5326, 0.2085, 0.9408, 1.1430,
#         0.7138, 8.2338, 0.3401, 0.3265, 8.4536, 0.9822, 1.9915, 0.3764, 0.1899,
#         8.9346, 3.0615, 0.5152, 2.7024, 2.2877], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(2004.0840, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8222, 0.4533, 0.1963, 0.5516, 0.9663, 0.0853, 0.9898, 0.3086, 0.6143,
#         0.8586, 0.5728, 0.3457, 0.8504, 0.1218, 0.7137, 0.9354, 0.7999, 0.0507,
#         0.5531, 0.8797, 0.4269, 0.9974, 0.4992, 0.3633, 0.3549, 0.7936, 0.0587,
#         0.4546, 0.9961, 0.6770, 0.8773, 0.4919], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([5.5457, 1.6491, 0.6280, 2.2932, 8.8323, 0.3370, 9.5258, 0.9887, 2.8191,
#         6.2377, 2.4595, 1.1326, 6.0750, 0.4301, 3.9012, 7.9946, 5.1593, 0.2447,
#         2.3047, 6.6788, 1.5066, 9.7643, 1.9257, 1.2062, 1.1705, 5.0546, 0.2671,
#         1.6562, 9.7213, 3.4614, 6.6268, 1.8790], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1965.4255, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3536, 0.2183, 0.1760, 0.2298, 0.2756, 0.2305, 0.5317, 0.8036, 0.5564,
#         0.4278, 0.5088, 0.3299, 0.7663, 0.9126, 0.7401, 0.1888, 0.6065, 0.4454,
#         0.5957, 0.2985, 0.0350, 0.5471, 0.0346, 0.9399, 0.3928, 0.2859, 0.1980,
#         0.8126, 0.7642, 0.4435, 0.4895, 0.5691], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.1651, 0.6913, 0.5718, 0.7258, 0.8722, 0.7278, 2.1461, 5.2222, 2.3298,
#         1.5112, 1.9886, 1.0695, 4.6275, 7.4265, 4.2495, 0.6070, 2.7485, 1.6055,
#         2.6525, 0.9518, 0.1982, 2.2592, 0.1968, 8.1108, 1.3389, 0.9072, 0.6328,
#         5.3758, 4.5959, 1.5949, 1.8641, 2.4298], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1853.6954, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.5837, 0.7477, 0.1320, 0.9876, 0.1474, 0.9078, 0.0769, 0.8709, 0.8611,
#         0.6941, 0.4519, 0.5140, 0.2117, 0.5779, 0.9971, 0.7025, 0.2386, 0.1635,
#         0.6001, 0.6268, 0.1578, 0.0161, 0.3488, 0.5032, 0.7727, 0.0590, 0.7031,
#         0.1495, 0.0983, 0.3177, 0.7469, 0.3468], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.5500, 4.3561, 0.4560, 9.4587, 0.4960, 7.3121, 0.3154, 6.4903, 6.2881,
#         3.6592, 1.6413, 2.0231, 0.6720, 2.5012, 9.7540, 3.7607, 0.7525, 0.5381,
#         2.6908, 2.9374, 0.5232, 0.1304, 1.1454, 1.9514, 4.7242, 0.2678, 3.7685,
#         0.5014, 0.3702, 1.0225, 4.3451, 1.1372], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1768.4995, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3880, 0.9177, 0.2122, 0.1114, 0.1283, 0.7653, 0.2754, 0.8276, 0.9159,
#         0.0867, 0.7479, 0.5796, 0.8684, 0.9036, 0.8365, 0.5258, 0.7493, 0.5134,
#         0.7482, 0.3872, 0.1052, 0.6718, 0.6663, 0.2884, 0.8206, 0.0285, 0.6248,
#         0.4499, 0.2025, 0.6272, 0.3601, 0.7281], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.3166, 7.5500, 0.6734, 0.4036, 0.4466, 4.6119, 0.8715, 5.6435, 7.5048,
#         0.3407, 4.3588, 2.5151, 6.4377, 7.2128, 5.8079, 2.1047, 4.3792, 2.0191,
#         4.3633, 1.3127, 0.3879, 3.4037, 3.3431, 0.9159, 5.5172, 0.1768, 2.9182,
#         1.6299, 0.6456, 2.9414, 1.1927, 4.0875], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1755.5420, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8215, 0.8255, 0.5786, 0.6727, 0.0355, 0.7364, 0.4982, 0.2594, 0.8275,
#         0.7939, 0.2962, 0.5222, 0.5966, 0.1065, 0.7704, 0.9481, 0.3631, 0.0223,
#         0.5764, 0.8711, 0.6060, 0.6478, 0.2646, 0.8081, 0.5938, 0.4803, 0.7072,
#         0.4468, 0.4486, 0.5273, 0.5216, 0.5526], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([5.5331, 5.6040, 2.5069, 3.4134, 0.1996, 4.1991, 1.9194, 0.8183, 5.6415,
#         5.0596, 0.9437, 2.0793, 2.6604, 0.3911, 4.6884, 8.3291, 1.2055, 0.1547,
#         2.4890, 6.4943, 2.7435, 3.1464, 0.8352, 5.2980, 2.6358, 1.8072, 3.8188,
#         1.6131, 1.6230, 2.1152, 2.0755, 2.3009], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1784.5125, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.8542, 0.2881, 0.6712, 0.3872, 0.8386, 0.9563, 0.3067, 0.9144, 0.6314,
#         0.2201, 0.7565, 0.1474, 0.8354, 0.9004, 0.9588, 0.1276, 0.9932, 0.7068,
#         0.0201, 0.6564, 0.1644, 0.1063, 0.3327, 0.6579, 0.0798, 0.4874, 0.5452,
#         0.0872, 0.3538, 0.0583, 0.6127, 0.6876], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([6.1499, 0.9150, 3.3968, 1.3126, 5.8483, 8.5519, 0.9816, 7.4702, 2.9822,
#         0.6965, 4.4819, 0.4960, 5.7868, 7.1397, 8.6216, 0.4448, 9.6329, 3.8142,
#         0.1463, 3.2360, 0.5406, 0.3906, 1.0805, 3.2523, 0.3230, 1.8509, 2.2450,
#         0.3419, 1.1663, 0.2659, 2.8045, 3.5834], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1684.5291, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2211, 0.4925, 0.2172, 0.5867, 0.2232, 0.6201, 0.0232, 0.3650, 0.4449,
#         0.5436, 0.8057, 0.1361, 0.2316, 0.8189, 0.6757, 0.7050, 0.7875, 0.0947,
#         0.6447, 0.8131, 0.8201, 0.5656, 0.9952, 0.2004, 0.6781, 0.6070, 0.3555,
#         0.9116, 0.1803, 0.7833, 0.9566, 0.0020], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.6995, 1.8826, 0.6882, 2.5751, 0.7057, 2.8739, 0.1583, 1.2136, 1.6027,
#         2.2328, 5.2576, 0.4667, 0.7311, 5.4856, 3.4469, 3.7919, 4.9557, 0.3612,
#         3.1148, 5.3847, 5.5080, 2.4015, 9.6955, 0.6395, 3.4733, 2.7531, 1.1734,
#         7.4021, 0.5835, 4.8893, 8.5605, 0.0444], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1686.9880, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6392, 0.3823, 0.8148, 0.7727, 0.1420, 0.2342, 0.9601, 0.5062, 0.7000,
#         0.7904, 0.0719, 0.8503, 0.4094, 0.1777, 0.0669, 0.3836, 0.9546, 0.0415,
#         0.8660, 0.9890, 0.6141, 0.0257, 0.3947, 0.9623, 0.5405, 0.8687, 0.3292,
#         0.0616, 0.5979, 0.9160, 0.7962, 0.5779], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.0597, 1.2903, 5.4134, 4.7238, 0.4818, 0.7390, 8.6554, 1.9716, 3.7306,
#         5.0036, 0.3023, 6.0727, 1.4185, 0.5765, 0.2892, 1.2963, 8.5033, 0.2181,
#         6.3882, 9.5037, 2.8176, 0.1671, 1.3476, 8.7174, 2.2099, 6.4453, 1.0668,
#         0.2750, 2.6715, 7.5082, 5.0980, 2.5015], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1632.0352, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([4.8693e-01, 1.0668e-02, 4.1515e-01, 4.0896e-04, 8.8505e-01, 1.3884e-01,
#         3.8559e-01, 6.4041e-01, 8.7077e-02, 3.8576e-01, 1.8234e-01, 1.6401e-01,
#         5.3808e-01, 1.0062e-01, 4.8635e-01, 7.1689e-02, 6.5410e-01, 3.7095e-01,
#         6.3882e-01, 3.3351e-01, 9.1007e-02, 2.6050e-01, 9.4940e-01, 2.9879e-02,
#         1.3816e-01, 7.1651e-01, 1.5451e-01, 8.1620e-01, 1.7263e-02, 2.7705e-01,
#         4.1815e-01, 1.4146e-01], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.8479, 0.1051, 1.4469, 0.0202, 6.7945, 0.4737, 1.3053, 3.0715, 0.3417,
#         1.3061, 0.5892, 0.5396, 2.1925, 0.3762, 1.8443, 0.3018, 3.2120, 1.2396,
#         3.0555, 1.0836, 0.3518, 0.8220, 8.3629, 0.1815, 0.4719, 3.9365, 0.5145,
#         5.4387, 0.1351, 0.8770, 1.4620, 0.4804], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1506.9874, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3373, 0.7801, 0.4128, 0.6455, 0.2715, 0.8079, 0.9508, 0.1137, 0.9259,
#         0.5598, 0.8815, 0.5320, 0.6178, 0.3626, 0.4545, 0.1540, 0.6889, 0.4993,
#         0.2739, 0.5493, 0.4934, 0.3223, 0.6116, 0.4543, 0.6965, 0.2256, 0.9135,
#         0.0461, 0.1035, 0.6865, 0.1368, 0.7915], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.0988, 4.8381, 1.4353, 3.1235, 0.8583, 5.2945, 8.4010, 0.4094, 7.7515,
#         2.3561, 6.7159, 2.1488, 2.8518, 1.2035, 1.6557, 0.5131, 3.5984, 1.9262,
#         0.8663, 2.2756, 1.8884, 1.0400, 2.7944, 1.6545, 3.6884, 0.7131, 7.4480,
#         0.2316, 0.3835, 3.5704, 0.4684, 5.0207], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1578.9312, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.5995, 0.0901, 0.9996, 0.6950, 0.0898, 0.8587, 0.6547, 0.7087, 0.3328,
#         0.7980, 0.1117, 0.1336, 0.2548, 0.9807, 0.7082, 0.3861, 0.3719, 0.2812,
#         0.2554, 0.0973, 0.8991, 0.0654, 0.5954, 0.3238, 0.5732, 0.3827, 0.7432,
#         0.0495, 0.0439, 0.5282, 0.9208, 0.2016], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.6858, 0.3493, 9.8321, 3.6699, 0.3486, 6.2391, 3.2188, 3.8372, 1.0807,
#         5.1278, 0.4043, 0.4601, 0.8036, 9.2517, 3.8316, 1.3075, 1.2440, 0.8912,
#         0.8055, 0.3677, 7.1098, 0.2852, 2.6494, 1.0459, 2.4627, 1.2921, 4.2925,
#         0.2413, 0.2253, 2.1218, 7.6248, 0.6431], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1498.3030, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6053, 0.0614, 0.0565, 0.4740, 0.7561, 0.0535, 0.6697, 0.9317, 0.3603,
#         0.9787, 0.2865, 0.9002, 0.0728, 0.3623, 0.8446, 0.3360, 0.1129, 0.4573,
#         0.3399, 0.1486, 0.6207, 0.8631, 0.0741, 0.7355, 0.7082, 0.3242, 0.5450,
#         0.0908, 0.2579, 0.8411, 0.2850, 0.3328], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.7375, 0.2744, 0.2610, 1.7690, 4.4765, 0.2528, 3.3801, 7.8994, 1.1934,
#         9.1919, 0.9094, 7.1360, 0.3047, 1.2019, 5.9618, 1.0933, 0.4075, 1.6718,
#         1.1090, 0.4989, 2.8799, 6.3296, 0.3081, 4.1873, 3.8314, 1.0473, 2.2434,
#         0.3512, 0.8137, 5.8952, 0.9041, 1.0808], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1437.4553, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2511, 0.8897, 0.5751, 0.3716, 0.3855, 0.5908, 0.2638, 0.4953, 0.7797,
#         0.2135, 0.8958, 0.1501, 0.8352, 0.5373, 0.2756, 0.9814, 0.2438, 0.5514,
#         0.4733, 0.9518, 0.1257, 0.8559, 0.5308, 0.0416, 0.9564, 0.2334, 0.3468,
#         0.8765, 0.7226, 0.1784, 0.2195, 0.3756], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.7917, 6.8983, 2.4783, 1.2425, 1.3049, 2.6098, 0.8329, 1.9006, 4.8317,
#         0.6774, 7.0347, 0.5030, 5.7838, 2.1866, 0.8719, 9.2708, 0.7687, 2.2915,
#         1.7649, 8.4290, 0.4399, 6.1833, 2.1400, 0.2185, 8.5550, 0.7365, 1.1369,
#         6.6099, 4.0147, 0.5784, 0.6950, 1.2603], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1463.7065, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2931, 0.0507, 0.9430, 0.1941, 0.5679, 0.8809, 0.9197, 0.7891, 0.5935,
#         0.7915, 0.6070, 0.6719, 0.2446, 0.0689, 0.3608, 0.4052, 0.2209, 0.3571,
#         0.8246, 0.1534, 0.1158, 0.9371, 0.8268, 0.4413, 0.2675, 0.9644, 0.7220,
#         0.4975, 0.9225, 0.2178, 0.4837, 0.2538], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.9327, 0.2448, 8.1924, 0.6217, 2.4198, 6.7046, 7.5995, 4.9819, 2.6333,
#         5.0201, 2.7532, 3.4044, 0.7713, 0.2944, 1.1956, 1.3979, 0.6991, 1.1798,
#         5.5886, 0.5115, 0.4147, 8.0362, 5.6284, 1.5828, 0.8449, 8.7762, 4.0072,
#         1.9147, 7.6666, 0.6899, 1.8282, 0.8003], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1454.3575, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.3242, 0.4384, 0.2295, 0.3941, 0.5741, 0.2472, 0.2738, 0.2331, 0.4771,
#         0.9656, 0.6986, 0.0986, 0.6345, 0.0396, 0.7034, 0.9075, 0.1124, 0.3828,
#         0.0029, 0.3719, 0.0787, 0.4311, 0.3213, 0.4259, 0.4264, 0.9964, 0.3602,
#         0.9598, 0.4203, 0.6920, 0.5150, 0.3280], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.0473, 1.5672, 0.7248, 1.3449, 2.4705, 0.7794, 0.8660, 0.7357, 1.7878,
#         8.8129, 3.7135, 0.3712, 3.0130, 0.2125, 3.7717, 7.3048, 0.4062, 1.2924,
#         0.0543, 1.2436, 0.3200, 1.5289, 1.0360, 1.5017, 1.5043, 9.7311, 1.1930,
#         8.6487, 1.4731, 3.6343, 2.0301, 1.0619], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(1376.0142, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.5961, 0.8399, 0.3224, 0.0452, 0.7252, 0.0501, 0.2323, 0.0462, 0.2172,
#         0.7802, 0.2449, 0.3994, 0.8084, 0.0560, 0.5509, 0.8779, 0.6086, 0.0520,
#         0.7657, 0.3792, 0.7486, 0.8948, 0.3033, 0.6834, 0.2928, 0.2628, 0.1903,
#         0.7767, 0.8784, 0.9746, 0.4756, 0.8690], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.6562, 5.8712, 1.0403, 0.2290, 4.0496, 0.2431, 0.7332, 0.2320, 0.6881,
# ...
#         0.3136, 0.9447, 0.7574, 0.1848, 0.1022, 0.3248, 0.4309, 0.7256, 0.3275,
#         0.8050, 0.7842, 0.7822, 0.1371, 0.6579], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.9757, 2.1371, 0.7832, 2.1366, 0.2635, 9.2147, 1.9877, 3.6377, 5.7727,
#         5.8065, 2.6894, 3.3409, 1.2961, 0.9579, 1.9947, 8.1110, 0.8472, 2.0838,
#         1.0073, 8.2378, 4.4949, 0.5960, 0.3803, 1.0495, 1.5276, 4.0545, 1.0599,
#         5.2445, 4.9034, 4.8713, 0.4691, 3.2522], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(80.4437, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1007, 0.5149, 0.1546, 0.9234, 0.3882, 0.4754, 0.7713, 0.4306, 0.2319,
#         0.7020, 0.6480, 0.6213, 0.8336, 0.6203, 0.6966, 0.6001, 0.1978, 0.2929,
#         0.5440, 0.9774, 0.0992, 0.8340, 0.0133, 0.8701, 0.1271, 0.5403, 0.9360,
#         0.8359, 0.7846, 0.0878, 0.0990, 0.9311], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.3764, 2.0295, 0.5147, 7.6909, 1.3174, 1.7775, 4.7022, 1.5262, 0.7319,
#         3.7549, 3.1483, 2.8847, 5.7535, 2.8755, 3.6891, 2.6910, 0.6322, 0.9319,
#         2.2360, 9.1533, 0.3726, 5.7606, 0.1176, 6.4745, 0.4436, 2.2086, 8.0097,
#         5.7959, 4.9094, 0.3437, 0.3721, 7.8825], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(94.7638, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2929, 0.7135, 0.2684, 0.3981, 0.4350, 0.4527, 0.7923, 0.3966, 0.6764,
#         0.6527, 0.9442, 0.2063, 0.2251, 0.7182, 0.6888, 0.8732, 0.8840, 0.1213,
#         0.5674, 0.5140, 0.4817, 0.3402, 0.6930, 0.0517, 0.5401, 0.9409, 0.1149,
#         0.4746, 0.0883, 0.8993, 0.7113, 0.3454], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.9320, 3.8985, 0.8480, 1.3637, 1.5494, 1.6455, 5.0339, 1.3566, 3.4544,
#         3.1972, 8.2241, 0.6565, 0.7116, 3.9588, 3.5967, 6.5400, 6.7716, 0.4287,
#         2.4159, 2.0237, 1.8158, 1.1104, 3.6465, 0.2477, 2.2071, 8.1378, 0.4126,
#         1.7728, 0.3447, 7.1152, 3.8709, 1.1313], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(84.8518, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4499, 0.6094, 0.0487, 0.0883, 0.7868, 0.3606, 0.7260, 0.5013, 0.5847,
#         0.7030, 0.0367, 0.7609, 0.4310, 0.9816, 0.5652, 0.8040, 0.7659, 0.3139,
#         0.0457, 0.6934, 0.4964, 0.2281, 0.8028, 0.7165, 0.4579, 0.3343, 0.8680,
#         0.1117, 0.6250, 0.5795, 0.9465, 0.9744], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.6303, 2.7743, 0.2393, 0.3448, 4.9452, 1.1947, 4.0599, 1.9393, 2.5577,
#         3.7672, 0.2034, 4.5462, 1.5280, 9.2769, 2.3986, 5.2279, 4.6212, 1.0082,
#         0.2306, 3.6516, 1.9076, 0.7204, 5.2077, 3.9364, 1.6752, 1.0866, 6.4293,
#         0.4042, 2.9199, 2.5145, 8.2856, 9.0648], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(89.5640, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6033, 0.7888, 0.4255, 0.0925, 0.9152, 0.0204, 0.3197, 0.8931, 0.8454,
#         0.0309, 0.8999, 0.7409, 0.8960, 0.3411, 0.8011, 0.6434, 0.7570, 0.1322,
#         0.5300, 0.6429, 0.0111, 0.4378, 0.3235, 0.3296, 0.0644, 0.7218, 0.7560,
#         0.2064, 0.5824, 0.5068, 0.3787, 0.1406], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.7195, 4.9765, 1.4993, 0.3557, 7.4894, 0.1478, 1.0300, 6.9738, 5.9778,
#         0.1848, 7.1272, 4.2605, 7.0383, 1.1141, 5.1791, 3.1011, 4.4897, 0.4566,
#         2.1341, 3.0962, 0.1072, 1.5643, 1.0445, 1.0682, 0.2826, 4.0046, 4.4748,
#         0.6568, 2.5385, 1.9751, 1.2741, 0.4782], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(100.3832, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2768, 0.3891, 0.9327, 0.5746, 0.9575, 0.4493, 0.2348, 0.9957, 0.9208,
#         0.0609, 0.5785, 0.9776, 0.1619, 0.4168, 0.5765, 0.0292, 0.6818, 0.7060,
#         0.2328, 0.6983, 0.9694, 0.4335, 0.6975, 0.4019, 0.5408, 0.0128, 0.1133,
#         0.7709, 0.7810, 0.6375, 0.6637, 0.0329], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.8762, 1.3215, 7.9242, 2.4744, 8.5850, 1.6266, 0.7408, 9.7102, 7.6259,
#         0.2732, 2.5061, 9.1583, 0.5341, 1.4553, 2.4899, 0.1794, 3.5164, 3.8045,
#         0.7347, 3.7096, 8.9200, 1.5415, 3.7008, 1.3817, 2.2126, 0.1154, 0.4083,
#         4.6969, 4.8533, 3.0423, 3.3145, 0.1914], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(100.4545, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1413, 0.5362, 0.6031, 0.0917, 0.2164, 0.1950, 0.4766, 0.5151, 0.5447,
#         0.0900, 0.4128, 0.1964, 0.2681, 0.2088, 0.6014, 0.5344, 0.2029, 0.5400,
#         0.8778, 0.0656, 0.7858, 0.3598, 0.4677, 0.7566, 0.4671, 0.2362, 0.2297,
#         0.0570, 0.1215, 0.7050, 0.0706, 0.2154], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.4800, 2.1786, 2.7180, 0.3536, 0.6857, 0.6242, 1.7845, 2.0308, 2.2413,
#         0.3491, 1.4350, 0.6283, 0.8469, 0.6636, 2.7025, 2.1657, 0.6468, 2.2067,
#         6.6382, 0.2858, 4.9284, 1.1915, 1.7320, 4.4835, 1.7284, 0.7451, 0.7254,
#         0.2624, 0.4293, 3.7914, 0.2991, 0.6829], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(93.0152, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.6524, 0.7498, 0.5930, 0.4641, 0.3526, 0.9511, 0.0061, 0.0123, 0.6901,
#         0.3696, 0.7883, 0.2985, 0.6825, 0.3691, 0.1536, 0.5505, 0.1369, 0.3744,
#         0.5873, 0.3932, 0.8964, 0.7812, 0.2378, 0.8326, 0.4390, 0.6143, 0.9163,
#         0.3111, 0.7108, 0.8668, 0.5666, 0.1966], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.1939, 4.3865, 2.6286, 1.7107, 1.1613, 8.4083, 0.0790, 0.1134, 3.6122,
#         1.2337, 4.9695, 0.9519, 3.5242, 1.2317, 0.5121, 2.2846, 0.4687, 1.2546,
#         2.5804, 1.3407, 7.0475, 4.8566, 0.7500, 5.7351, 1.5704, 2.8192, 7.5159,
#         0.9977, 3.8644, 6.4048, 2.4097, 0.6287], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(93.7613, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.0872, 0.6212, 0.1838, 0.1473, 0.2532, 0.4041, 0.9407, 0.6908, 0.2116,
#         0.5867, 0.0649, 0.5770, 0.4038, 0.6134, 0.8460, 0.2558, 0.4516, 0.4656,
#         0.6345, 0.1459, 0.0034, 0.8374, 0.5042, 0.1190, 0.4569, 0.0900, 0.4236,
#         0.0757, 0.9513, 0.7682, 0.1590, 0.6137], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.3419, 2.8845, 0.5933, 0.4955, 0.7985, 1.3927, 8.1310, 3.6206, 0.6717,
#         2.5754, 0.2839, 2.4942, 1.3909, 2.8116, 5.9886, 0.8068, 1.6399, 1.7196,
#         3.0122, 0.4921, 0.0590, 5.8252, 1.9584, 0.4228, 1.6695, 0.3492, 1.4899,
#         0.3123, 8.4141, 4.6559, 0.5264, 2.8142], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(101.2266, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.5692, 0.6945, 0.3382, 0.2159, 0.6437, 0.2239, 0.1914, 0.3181, 0.6862,
#         0.9481, 0.9734, 0.4877, 0.8190, 0.3464, 0.6849, 0.5410, 0.7482, 0.9473,
#         0.7307, 0.8657, 0.6830, 0.2542, 0.1952, 0.9342, 0.7048, 0.8417, 0.9410,
#         0.0148, 0.3806, 0.4064, 0.0449, 0.2531], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.4302, 3.6646, 1.1023, 0.6842, 3.1049, 0.7078, 0.6143, 1.0241, 3.5665,
#         8.3282, 9.0367, 1.8527, 5.4886, 1.1355, 3.5514, 2.2142, 4.3629, 8.3071,
#         4.1229, 6.3819, 3.5298, 0.8017, 0.6250, 7.9615, 3.7893, 5.9060, 8.1389,
#         0.1247, 1.2826, 1.4036, 0.2280, 0.7980], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(91.1773, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7086, 0.7591, 0.2182, 0.9484, 0.4856, 0.1795, 0.7306, 0.4790, 0.9128,
#         0.8100, 0.7240, 0.7000, 0.8642, 0.1738, 0.5859, 0.8163, 0.6521, 0.1199,
#         0.1428, 0.9528, 0.2645, 0.7277, 0.5821, 0.3506, 0.3872, 0.1697, 0.9760,
#         0.1904, 0.6338, 0.1855, 0.8247, 0.2168], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([3.8363, 4.5206, 0.6909, 8.3348, 1.8396, 0.5814, 4.1208, 1.7992, 7.4318,
#         5.3310, 4.0336, 3.7301, 6.3510, 0.5659, 2.5686, 5.4404, 3.1908, 0.4252,
#         0.4839, 8.4550, 0.8351, 4.0821, 2.5364, 1.1529, 1.3128, 0.5549, 9.1131,
#         0.6114, 3.0055, 0.5977, 5.5906, 0.6869], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(82.2695, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.2213, 0.9660, 0.9444, 0.4706, 0.4416, 0.3397, 0.2980, 0.5521, 0.5837,
#         0.6051, 0.0754, 0.1327, 0.0153, 0.0505, 0.7645, 0.8044, 0.3407, 0.0870,
#         0.7145, 0.4609, 0.9943, 0.7110, 0.6660, 0.8389, 0.3672, 0.7169, 0.1111,
#         0.3704, 0.0845, 0.9890, 0.3904, 0.0957], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.7002, 8.8217, 8.2294, 1.7486, 1.5844, 1.1083, 0.9500, 2.2967, 2.5499,
#         2.7357, 0.3115, 0.4580, 0.1270, 0.2442, 4.6002, 5.2353, 1.1124, 0.3415,
#         3.9103, 1.6925, 9.6648, 3.8661, 3.3394, 5.8530, 1.2231, 3.9411, 0.4029,
#         1.2370, 0.3350, 9.5024, 1.3276, 0.3636], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(95.6917, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([5.8126e-01, 2.8595e-04, 3.9833e-01, 3.6130e-01, 9.1067e-01, 2.1591e-01,
#         3.8900e-01, 5.7699e-01, 5.0166e-01, 7.9991e-01, 4.1572e-01, 3.4679e-01,
#         3.7897e-01, 2.0914e-01, 9.9661e-02, 9.2846e-02, 7.4862e-01, 7.9109e-01,
#         1.5500e-01, 5.8962e-01, 4.9069e-01, 9.6487e-01, 1.8737e-02, 5.2100e-01,
#         2.6617e-01, 4.3612e-01, 7.2864e-01, 5.3011e-01, 6.5899e-02, 1.5550e-01,
#         4.2098e-01, 7.6964e-02], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([2.5292, 0.0169, 1.3649, 1.1978, 7.3804, 0.6843, 1.3210, 2.4939, 1.9415,
#         5.1594, 1.4498, 1.1371, 1.2753, 0.6646, 0.3738, 0.3565, 4.3692, 5.0141,
#         0.5158, 2.5999, 1.8714, 8.7907, 0.1411, 2.0713, 0.8405, 1.5552, 4.0948,
#         2.1351, 0.2865, 0.5171, 1.4764, 0.3156], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(117.5439, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.7819, 0.5269, 0.2604, 0.8560, 0.6571, 0.3119, 0.6043, 0.3077, 0.1354,
#         0.3106, 0.2360, 0.0753, 0.0534, 0.2269, 0.0050, 0.9428, 0.2682, 0.8909,
#         0.3163, 0.7042, 0.9779, 0.7206, 0.1798, 0.5814, 0.3207, 0.7093, 0.7622,
#         0.8020, 0.4463, 0.4085, 0.2337, 0.3823], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([4.8671, 2.1126, 0.8216, 6.1867, 3.2439, 1.0008, 2.7285, 0.9853, 0.4647,
#         0.9958, 0.7444, 0.3112, 0.2525, 0.7171, 0.0709, 8.1861, 0.8471, 6.9243,
#         1.0174, 3.7820, 9.1675, 3.9888, 0.5821, 2.5303, 1.0338, 3.8458, 4.5665,
#         5.1950, 1.6105, 1.4139, 0.7376, 1.2905], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(94.9033, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.4890, 0.1748, 0.4759, 0.9182, 0.1888, 0.1668, 0.7338, 0.3791, 0.7093,
#         0.1126, 0.9568, 0.2280, 0.9314, 0.3519, 0.8164, 0.8342, 0.2858, 0.9274,
#         0.2998, 0.0780, 0.9814, 0.1374, 0.8671, 0.4997, 0.7514, 0.4457, 0.1994,
#         0.5649, 0.3274, 0.1206, 0.3141, 0.2253], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([1.8606, 0.5684, 1.7803, 7.5615, 0.6071, 0.5470, 4.1636, 1.2759, 3.8457,
#         0.4067, 8.5660, 0.7204, 7.8911, 1.1580, 5.4417, 5.7653, 0.9070, 7.7908,
#         0.9564, 0.3182, 9.2726, 0.4700, 6.4125, 1.9291, 4.4090, 1.6070, 0.6367,
#         2.3965, 1.0597, 0.4271, 1.0089, 0.7120], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(82.3084, device='cuda:0', grad_fn=<MeanBackward0>)
# random_t torch.Size([32]) random_t tensor([0.1079, 0.5699, 0.9246, 0.1765, 0.2953, 0.3969, 0.7664, 0.8606, 0.6488,
#         0.5180, 0.5516, 0.2631, 0.2033, 0.3222, 0.8938, 0.9341, 0.5835, 0.7766,
#         0.9487, 0.9537, 0.7768, 0.5413, 0.6558, 0.3483, 0.6686, 0.2765, 0.4272,
#         0.6776, 0.2415, 0.3140, 0.9552, 0.9518], device='cuda:0')
# z torch.Size([32, 1, 28, 28])
# 经过时间embed之后，时间t的shape： torch.Size([32, 256])
# h: torch.Size([32, 128, 5, 5])
# torch.Size([32, 128, 5, 5])
# score.shape: torch.Size([32, 1, 28, 28])
# std tensor([0.3947, 2.4359, 7.7194, 0.5731, 0.9404, 1.3580, 4.6292, 6.2790, 3.1573,
#         2.0504, 2.2928, 0.8305, 0.6478, 1.0396, 6.9889, 7.9592, 2.5477, 4.7836,
#         8.3445, 8.4792, 4.7877, 2.2158, 3.2299, 1.1435, 3.3677, 0.8752, 1.5085,
#         3.4682, 0.7617, 1.0087, 8.5211, 8.4276], device='cuda:0') torch.Size([32])
# torch.Size([32])
# torch.Size([32, 28, 28])
# torch.Size([32, 1, 28])
# torch.Size([32, 1, 28])
# loss tensor(75.6738, device='cuda:0', grad_fn=<MeanBackward0>)
# 100%|██████████| 1/1 [00:28<00:00, 28.29s/it]
# Average ScoreMatching Loss:305.608176

# %% [markdown]
# ![路径](Images/Images_for_ScoreBasedModel/20230330233422.png) “采样“

# %%
num_steps = 500;

def euler_sampler(
        score_model,
        marginal_prob_std,
        batch_size=64,
        num_steps=num_steps,
        device='cuda',
        eps=1e-3,
):
    t = torch.ones(batch_size,device= device)
    init_x = torch.randn(batch_size,1,28,28,device=device)\
        * marginal_prob_std(t)[:,None,None,None]

    time_steps = torch.linspace(1.,eps,num_steps,device=device)
    # delta t
    step_size = time_steps[0] - time_steps[1]

    x = init_x
    with torch.no_grad():
        for time_step in tqdm.tqdm(time_steps):
            batch_time_step = torch.ones(batch_size,device=device)*time_step
            g = diffusion_coeff(batch_time_step)
            mean_x = x + (g**2)[:,None,None,None]*score_model(x,batch_time_step)*step_size
            x = mean_x + torch.sqrt(step_size) *g[:,None,None,None]*torch.randn_like(x)
    return mean_x

# %% [markdown]
# 欧拉算法和郎之万采样直接的PC采样法：
# ![路径](Images/Images_for_ScoreBasedModel/20230331232719.png)

# %%
signal_to_noise_ratio = 0.16
num_steps = 500
def PC_sampler(
        score_model,
        marginal_prob_std,
        batch_size = 64,
        num_steps=num_steps,
        snr = signal_to_noise_ratio,
        device ="cuda",
        eps = 1e-3
):
    t = torch.ones(batch_size,device = device)
    init_x = torch.randn(batch_size,1,28,28,device=device)*marginal_prob_std(t)[:,None,None,None]
    
    time_steps = np.linspace(1.,eps,num_steps)
    step_size = time_steps[0]-time_steps[1]
    
    # 重复交替的进行欧拉数值求解：
    x = init_x
    with torch.no_grad():
        for time_step in tqdm.tqdm(time_steps):
            batch_time_step = torch.ones(batch_size,device=device)*time_step
            
            grad = score_model(x,batch_time_step)
            grad_norm = torch.norm(grad.reshape((grad.shape[0],-1),dim = -1)).mean()
            noise_norm = np.sqrt(np.prod(x.shape[1:]))
            # 步长，snr是为了保证每一步的信噪比是固定量级的。
            Langevin_step_size = 2*(snr*noise_norm/grad_norm)**2
            print(f"{Langevin_step_size=}")
            
            #做 10 步 矫正：
            for _ in range(10):
                x = x + Langevin_step_size*grad+torch.sqrt(2*Langevin_step_size)*torch.rand_like(x)
                qrad = score_model(x,batch_time_step)
                grad_norm = torch.norm(grad.reshape((grad.shape[0],-1),dim = -1)).mean()
                noise_norm = np.sqrt(np.prod(x.shape[1:]))
                Langevin_step_size = 2*(snr*noise_norm/grad_norm)**2
                print(f"{Langevin_step_size=}")
            
        # Predictor
        g = diffusion_coeff(batch_time_step)
        x_mean = x + (g**2)[:,None,None,None]*score_model(x,batch_time_step)*step_size
        x = x_mean +torch.sqrt(g**2*step_size)[:,None,None,None]*torch.randn_like(x)
    
    return x_mean
